# %% [markdown]
# # Polynomial Linear Regression

# %% [markdown]
# > Formula: $y = b_0 + b_1 * x_1 + b_2 * x_1^2 + \dots + b_n *x_1^n$
# $y$ is dependent variable (DV)
# $x_1$ is independent variables (IV)
# $b_1 \dots b_n$ is coefficient - How much affected that x does to y
# $b_0$ is constant (intercept)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
poly_feat = PolynomialFeatures(4)
X_poly = poly_feat.fit_transform(X)
poly_regressor = LinearRegression()
poly_regressor.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, y, color='red')
plt.plot(X, regressor.predict(X), color='blue')
plt.title('Truth of Bluff (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y, color='red')
plt.plot(X, poly_regressor.predict(X_poly), color='blue')
plt.title('Truth of Bluff (Polynomial Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
X_poly_grid = poly_feat.fit_transform(X_grid)
plt.scatter(X, y, color='red')
plt.plot(X_grid, poly_regressor.predict(X_poly_grid), color='blue')
plt.title('Truth of Bluff (Polynomial Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
poly_regressor.predict(poly_feat.fit_transform([[6.5]]))
# Out:
# array([158862.45265153])
